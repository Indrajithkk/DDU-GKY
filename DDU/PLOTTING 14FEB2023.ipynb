# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("Car_sales.csv")

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ## droping na values

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %% [markdown]
# ## plots on numerical values

# %%
### ploting
data.Horsepower.plot.hist(figsize=(6,3), cmap= 'brg') ;

# %%
## create box plot
data.Sales_in_thousands.plot.box(figsize=(6,6), cmap= 'rainbow');

# %%
data.Horsepower.plot.box(figsize=(6,3), cmap= 'Wistia_r') ;

# %% [markdown]
# ## sub plots

# %%
data.plot.box(figsize=(22,3), subplots= True);

# %% [markdown]
# data.plot.hist(figsize=(6,22), subplot = True );

# %%
data.plot.hist(figsize=(3,20), subplots = True );
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data.sort_values(by='__year_resale_value').plot.line('__year_resale_value','Price_in_thousands',figsize=(6,3),cmap='Wistia_r');

# %% [markdown]
# ## bar plot

# %%
data.head(1)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919                16.36    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
#
#    Power_perf_factor
# 0           58.28015

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(6,2),cmap='twilight_shifted')
# Out:
# <AxesSubplot:>

# %%
data.Vehicle_type.value_counts().plot.bar(figsize=(2,4),cmap='twilight_shifted')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Area chart

# %%
data.plot.area('Manufacturer','Power_perf_factor', figsize=(10,3),cmap='gist_rainbow');

# %% [markdown]
# ## Horizontal bar chart

# %%
data.sort_values( by ='Price_in_thousands')[:5].plot.barh('Model','Power_perf_factor', figsize=(6,4));

# %% [markdown]
# ## scatter plot

# %%
data.sort_values( by ='Price_in_thousands')[:5].plot.scatter('Model','Power_perf_factor', figsize=(6,4));

# %%
data.plot.box(figsize=(22,10));

# %%
data.sort_values(by='Engine_size',ascending=False)[:10].Engine_size.plot.pie();

# %% [markdown]
# ## KDE PLOT

# %%
data.plot.kde(figsize=(10,3.8));

# %%
data.plot.kde(figsize=(10,20),subplots=True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## HEXBIN PLOT

# %%
data.plot.hexbin('Curb_weight','Fuel_capacity',gridsize=15,cmap='gist_rainbow')
# Out:
# <AxesSubplot:xlabel='Curb_weight', ylabel='Fuel_capacity'>
