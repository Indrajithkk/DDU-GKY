# %% [markdown]
# ## KLIB
#
# #### klib library enables us to quikly visualize the missing data , perform data cleaning, visualize data distribution plot , visualize corelation plot and visualize catogorical column values.  " Klib is a python library for importing , cleaning  , analyzing , and preprocessing the data "

# %%
import klib as k
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pip install klib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_csv('Car_sales.csv')

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data['data'] = data['Wheelbase'].fillna(0)
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
k.cat_plot(data);

# %%
k.dist_plot(data);

# %%
k.missingval_plot(data);

# %%
k.describe
# Out:
# <module 'klib.describe' from 'C:\\Users\\USER\\anaconda3\\lib\\site-packages\\klib\\describe.py'>

# %%
data_cleaned = k.data_cleaning(data)
# Out:
# Shape of cleaned data: (157, 17) - Remaining NAs: 51
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.01 MB (-50.0%)

# %%
data_cleaned
# Out:
#     manufacturer    model  sales_in_thousands  year_resale_value vehicle_type  \
# 0          Acura  Integra           16.919001          16.360001    Passenger
# 1          Acura       TL           39.383999          19.875000    Passenger
# 2          Acura       CL           14.114000          18.225000    Passenger
# 3          Acura       RL            8.588000          29.725000    Passenger
# 4           Audi       A4           20.396999          22.254999    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40            3.545000                NaN    Passenger
# 153        Volvo      S70           15.245000                NaN    Passenger
# 154        Volvo      V70           17.531000                NaN    Passenger
# 155        Volvo      C70            3.493000                NaN    Passenger
# 156        Volvo      S80           18.969000                NaN    Passenger
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacturer        157 non-null    string
#  1   model               157 non-null    string
#  2   sales_in_thousands  157 non-null    float32
#  3   year_resale_value   121 non-null    float32
#  4   vehicle_type        157 non-null    category
#  5   price_in_thousands  155 non-null    float32
#  6   engine_size         156 non-null    float32
#  7   horsepower          156 non-null    float32
#  8   wheelbase           156 non-null    float32
#  9   width               156 non-null    float32
#  10  length              156 non-null    float32
#  11  curb_weight         155 non-null    float32
#  12  fuel_capacity       156 non-null    float32
#  13  fuel_efficiency     154 non-null    float32
#  14  latest_launch       157 non-null    string
# ...

# %%
k.corr_plot(data=data, annot=False);

# %% [markdown]
# ## Display only positive correlation

# %%
## pos is positive correlation
k.corr_plot(data_cleaned, split='pos', annot=False);
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.

# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Display only negative correlation

# %%
##  neg is negative correlation
k.corr_plot(data_cleaned, split='neg', annot=False);
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.

# %%
k.corr_mat(data)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## Display correlation with a target variablenof intrest

# %%
k.corr_plot(data=data, target='Price_in_thousands');
