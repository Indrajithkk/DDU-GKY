# %% [markdown]
# ## POSSUM DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor , \
GradientBoostingRegressor, BaggingRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.svm import LinearSVR

# %%
df=pd.read_csv("possum.csv")

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.tail()
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5

# %%
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %%
df.isnull().sum()
# Out:
# case        0
# site        0
# Pop         0
# sex         0
# age         2
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    1
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      104 non-null    int64
#  1   site      104 non-null    int64
#  2   Pop       104 non-null    object
#  3   sex       104 non-null    object
#  4   age       102 non-null    float64
#  5   hdlngth   104 non-null    float64
#  6   skullw    104 non-null    float64
#  7   totlngth  104 non-null    float64
#  8   taill     104 non-null    float64
#  9   footlgth  103 non-null    float64
#  10  earconch  104 non-null    float64
#  11  eye       104 non-null    float64
#  12  chest     104 non-null    float64
#  13  belly     104 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 11.5+ KB

# %%
df.shape
# Out:
# (104, 14)

# %%
df.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %%
df.isnull().mean()*100
# Out:
# case        0.000000
# site        0.000000
# Pop         0.000000
# sex         0.000000
# age         1.923077
# hdlngth     0.000000
# skullw      0.000000
# totlngth    0.000000
# taill       0.000000
# footlgth    0.961538
# earconch    0.000000
# eye         0.000000
# chest       0.000000
# belly       0.000000
# dtype: float64

# %% [markdown]
# ## filling the nan value

# %%
### fill the nan value of the column age
df.age.fillna(df.age.mean(),inplace=True)
df.footlgth.fillna(df.footlgth.mean(),inplace=True)
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %%
## cleard the nan values 
df.isnull().sum()*100
# Out:
# case        0
# site        0
# Pop         0
# sex         0
# age         0
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    0
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %% [markdown]
# ## Univariate analysis

# %%
## Univariate Analysis is a type of data visualization.
## where we visualize only a single variable at a time.
for i in df.columns:
    if df[i].dtype !="object":
        sns.histplot(x = df[i] )
        plt.show()

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.kdeplot(x = df[i],color="red")
        plt.show()

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.boxplot(y=df[i], color="white")
        plt.show()

# %% [markdown]
# ## Setting the outliers limits

# %%
def outliear_limit(col):
    Q3,Q1=np.nanpercentile(col,[75,25])
    IQR = Q3-Q1
    UL = Q3+1.5*IQR
    LL = Q1-1.5*Q1
    return UL,LL

# %%
for i in df.columns:
    if df[i].dtype !="object":
        UL,LL = outliear_limit(df[i])
        df[i] = np.where((df[i]>UL)|(df[i]<LL), np.nan, df[i])

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.boxplot(y=df[i],color="green")
        plt.show()

# %% [markdown]
# ## Drop the columns

# %%
df.dropna(inplace=True)## remove the nan from the outliears

# %%
df.isnull().sum()
# Out:
# case        0
# site        0
# Pop         0
# sex         0
# age         0
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    0
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %%
df
# Out:
#       case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0      1.0   1.0    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1      2.0   1.0    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2      3.0   1.0    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3      4.0   1.0    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4      5.0   1.0    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..     ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99   100.0   7.0  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100  101.0   7.0  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101  102.0   7.0  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102  103.0   7.0  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103  104.0   7.0  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %% [markdown]
# ## Label Encoding the categorical columns

# %%
## labelencoding is to change a column integer into numerical values or to change machine lerning
##  assign labelencoder into  VARIABLE "le"

le = LabelEncoder()

# %%
df['Pop']=le.fit_transform(df['Pop'])

# %%
df['sex']=le.fit_transform(df['sex'])

# %%
df
# Out:
#       case  site  Pop  sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0      1.0   1.0    0    1  8.0     94.1    60.4      89.0   36.0      74.5
# 1      2.0   1.0    0    0  6.0     92.5    57.6      91.5   36.5      72.5
# 2      3.0   1.0    0    0  6.0     94.0    60.0      95.5   39.0      75.4
# 3      4.0   1.0    0    0  6.0     93.2    57.1      92.0   38.0      76.1
# 4      5.0   1.0    0    0  2.0     91.5    56.3      85.5   36.0      71.0
# ..     ...   ...  ...  ...  ...      ...     ...       ...    ...       ...
# 99   100.0   7.0    1    1  1.0     89.5    56.0      81.5   36.5      66.0
# 100  101.0   7.0    1    1  1.0     88.6    54.7      82.5   39.0      64.4
# 101  102.0   7.0    1    0  6.0     92.4    55.0      89.0   38.0      63.5
# 102  103.0   7.0    1    1  4.0     91.5    55.2      82.5   36.5      62.9
# 103  104.0   7.0    1    0  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %% [markdown]
# ### checking the correlation with the target "footlgth"

# %%
sns.heatmap(df.corr()[["footlgth"]].sort_values(by="footlgth", ascending=False), vmin=1, annot=True,cmap="autumn");

# %% [markdown]
# ## Lets take only column with good correlation with the target

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      91 non-null     float64
#  1   site      91 non-null     float64
#  2   Pop       91 non-null     int32
#  3   sex       91 non-null     int32
#  4   age       91 non-null     float64
#  5   hdlngth   91 non-null     float64
#  6   skullw    91 non-null     float64
#  7   totlngth  91 non-null     float64
#  8   taill     91 non-null     float64
#  9   footlgth  91 non-null     float64
#  10  earconch  91 non-null     float64
#  11  eye       91 non-null     float64
#  12  chest     91 non-null     float64
#  13  belly     91 non-null     float64
# dtypes: float64(12), int32(2)
# memory usage: 10.0 KB

# %%
x=df[['hdlngth','skullw','totlngth','earconch','chest','belly']].values

# %%
y=df[['footlgth']].values

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %% [markdown]
# ## Splitting the data into training and testing data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Model building

# %%
models = {
    "LinearRegression": LinearRegression(),
    "Ridge" : Ridge(),
    "LinearSVR": LinearSVR(),
    "Lasso" : Lasso(),
    "GradientBoostingRegressor":GradientBoostingRegressor(),
    "BaggingRegressor" : BaggingRegressor(),
    "GradientBoostingRegressor":GradientBoostingRegressor(),
    "HistGradientBoostingRegressor": HistGradientBoostingRegressor(),
    "DecisionTreeRegressor" : DecisionTreeRegressor(),
    "AdaBoostRegressor" : AdaBoostRegressor(),
    "RandomForestRegressor" : RandomForestRegressor(random_state=0),
}

# %%
for name, model in models.items():
    model.fit(x_train,y_train)
    print("model trained with {}".format(name))
    training_score = model.score(x_train , y_train)*100
    testing_score = model.score(x_test , y_test)*100
    score = r2_score(y_test , model.predict(x_test))*100
    mae = mean_absolute_error(y_test,model.predict(x_test))
    mse = mean_squared_error(y_test, model.predict(x_test))
    rmse = np.sqrt(mse)
    print("r2score:",score)
    print("training_score:",training_score)
    print("testing_score:", testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test:",rmse)
    print("*"*100)
# Out:
# model trained with LinearRegression
# r2score: 67.70984649411095
# training_score: 74.21854194048952
# testing_score: 67.70984649411095
# mae: 1.9072683350200645
# mse: 5.4436010919229965
# rmse_test: 2.333152607936951
# ****************************************************************************************************
# model trained with Ridge
# r2score: 67.91111526057854
# training_score: 74.20226887969041
# testing_score: 67.91111526057854
# mae: 1.9029375162099134
# mse: 5.409670411577571
# rmse_test: 2.3258698182782225
# ****************************************************************************************************
# model trained with LinearSVR
# r2score: -64.45169040689296
# training_score: -17.80603340511293
# testing_score: -64.45169040689296
# mae: 4.498383219746529
# mse: 27.723912842479283
# rmse_test: 5.265350210810225
# ****************************************************************************************************
# model trained with Lasso
# ...
